# %% [markdown]
# # Homework 11: Regression Inference

# %% [markdown]
# **Reading**:
# * [Inference for Regression](https://www.inferentialthinking.com/chapters/16/inference-for-regression.html)

# %% [markdown]
# Please complete this notebook by filling in the cells provided. Before you begin, execute the following cell to load the provided tests. Each time you start your server, you will need to execute this cell again to load the tests.
#
# Directly sharing answers is not okay, but discussing problems with the course staff or with other students is encouraged. Refer to the policies page to learn more about how to learn cooperatively.
#
# For all problems that you must write our explanations and sentences for, you **must** provide your answer in the designated space. Moreover, throughout this homework and all future ones, please be sure to not re-assign variables throughout the notebook! For example, if you use `max_temperature` in your answer to one question, do not reassign it later on.

# %%
# Don't change this cell; just run it. 

import numpy as np
from datascience import *

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)
from matplotlib import patches
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# These lines load the tests.

from gofer.ok import check

# %% [markdown]
# ## 1. Visual Diagnostics for Linear Regression

# %% [markdown]
# ### Regression Model Diagnostics
# Linear regression isn't always the best way to describe the relationship between two variables. We'd like to develop techniques that will help us decide whether or not to use a linear model to predict one variable based on another.
#
# We will use the insight that if a regression fits a set of points well, then the residuals from that regression line will show no pattern when plotted against the predictor variable.
#
# The table below contains information about crime rates and median home values in suburbs of Boston. We will attempt to use linear regression to predict median home value in terms of crime rate.
#
# #### About the dataset
# All data are from 1970.  Crime rates are per capita per year; home values are in thousands of dollars.  The crime data come from the FBI, and home values are from the US Census Bureau.
#
# Run the next cell to load the data and see a scatter plot.

# %%
boston = Table.read_table('boston_housing.csv')
boston.scatter('Crime Rate')

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 1
#
# Write a function called `residuals`.  It should take a single argument, a table.  It should first compute the slope and intercept of the regression line that predicts the second column of that table (accessible as `tbl.column(1)`) using the first column (`tbl.column(0)`). The function should return an array containing the *residuals* for that regression line. Recall that residuals are given by
#
# $$residual = observed \ value - regression \ estimate$$
#
# Hint: If your code is getting long, think about how you can split the problem up into multiple smaller, simpler functions.

# %%
def residuals(tbl):
    x_val = tbl.column(0)
    y_val = tbl.column(1)
    x_su = (x_val-np.mean(x_val))/np.std(x_val)
    y_su = (y_val-np.mean(y_val))/np.std(y_val)
    r = np.mean(x_su * y_su)
    slope = r * (np.std(y_val)/np.std(x_val))
    intercept = np.mean(y_val) - slope * np.mean(x_val)
    predicted = tbl.column(0) * slope + intercept
    return tbl.column(1) - predicted

# %%
check('tests/q1_1.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 2
#
# Make a scatter plot of the residuals for the Boston housing dataset against crime rate. Crime rate should be on the horizontal axis.

# %%
boston = boston.with_column("Residuals", residuals(boston))
boston.scatter(0,2)

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 3
#
# Does the plot of residuals look roughly like a formless cloud, or is there some kind of pattern? Are they centered around 0?

# %% [markdown]
# No, it doesn't look like a formless cloud, most of the points are along the y axis and there are some scattered around.

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 4
#
# Does it seem like a linear model is appropriate for describing the relationship between crime and median home value?
#
# Assign `linear` to `True` if a linear model is appropriate for describing the relationship, and `False` if it is not.

# %%
linear = False

# %%
check('tests/q1_4.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# Section [15.6](https://www.inferentialthinking.com/chapters/15/6/numerical-diagnostics.html) of the textbook describes some mathematical facts that hold for all regression estimates, regardless of goodness of fit.  One fact is that there is a relationship between the standard deviation of the residuals, the standard deviation of the response variable, and the correlation.  Let us test this.

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 5
#
# Directly compute the standard deviation of the residuals from the Boston data.  Then compute the same quantity without using the residuals, using the formula described in section 15.6 [here](https://www.inferentialthinking.com/chapters/15/6/Numerical_Diagnostics.html#sd-of-the-residuals) instead.

# %%
bx_standard = (boston.column(0) - np.mean(boston.column(0)))/np.std(boston.column(0))
by_standard = (boston.column(1) - np.mean(boston.column(1)))/np.std(boston.column(1))
br = np.mean(bx_standard * by_standard)

boston_residual_sd = np.std(residuals(boston))
boston_residual_sd_from_formula = ((1-br**2)**.5)*np.std(boston.column(1))

print("Residual SD: {0}".format(boston_residual_sd))
print("Residual SD from the formula: {0}".format(boston_residual_sd_from_formula))
# Out:
# Residual SD: 8.474144781120948
# Residual SD from the formula: 8.474144781120948

# %%
check('tests/q1_5.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# Below, we have imported a new table, the Old Faithful data.

# %%
old_faithful = Table.read_table('faithful.csv')
old_faithful
# Out:
# duration | wait
# 3.6      | 79
# 1.8      | 54
# 3.333    | 74
# 2.283    | 62
# 4.533    | 85
# 2.883    | 55
# 4.7      | 88
# 3.6      | 85
# 1.95     | 51
# 4.35     | 85
# ... (262 rows omitted)

# %% [markdown]
# The following cell makes a residual plot for this new dataset.

# %%
Table().with_columns('Residual', residuals(old_faithful), 'Duration', old_faithful.column('duration')).scatter('Duration')

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 6
#
# Repeat the procedure from Question 5 to find the standard deviation of the residuals for the `old_faithful` dataset.

# %%
fx_standard = (old_faithful.column(0) - np.mean(old_faithful.column(0)))/np.std(old_faithful.column(0))
fy_standard = (old_faithful.column(1) - np.mean(old_faithful.column(1)))/np.std(old_faithful.column(1))
fr = np.mean(fx_standard * fy_standard)

faithful_residual_sd = np.std(residuals(old_faithful))
faithful_residual_sd_from_formula = ((1-fr**2)**.5)*np.std(old_faithful.column(1))

print("Residual SD: {0}".format(faithful_residual_sd))
print("Residual SD from the formula: {0}".format(faithful_residual_sd_from_formula))
# Out:
# Residual SD: 5.892226635893954
# Residual SD from the formula: 5.892226635893948

# %%
check('tests/q1_6.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# ## 2. Finding the Least Squares Regression Line

# %% [markdown]
# In this exercise, you'll work with a small invented data set.  Run the next cell to generate the dataset `d` and see a scatter plot.

# %%
d = Table().with_columns(
    'x', make_array(0,  1,  2,  3,  4),
    'y', make_array(1, .5, -1,  2, -3))
d.scatter('x')

# %% [markdown]
# #### Question 1 (Ungraded, but you'll need the result later)
# Running the cell below will generate sliders that control the slope and intercept of a line through the scatter plot.  When you adjust a slider, the line will move.
#
# By moving the line around, make your best guess at the least-squares regression line.  (It's okay if your line isn't exactly right, as long as it's reasonable.)
#
# **Note:** Python will probably take about a second to redraw the plot each time you adjust the slider.  We suggest clicking the place on the slider you want to try and waiting for the plot to be drawn; dragging the slider handle around will cause a long lag.

# %%
def plot_line(slope, intercept):
    plt.figure(figsize=(5,5))
    
    endpoints = make_array(-2, 7)
    p = plt.plot(endpoints, slope*endpoints + intercept, color='orange', label='Proposed line')
    
    plt.scatter(d.column('x'), d.column('y'), color='blue', label='Points')
    
    plt.xlim(-4, 8)
    plt.ylim(-6, 6)
    plt.gca().set_aspect('equal', adjustable='box')
    
    plt.legend(bbox_to_anchor=(1.8, .8))
    plt.show()

interact(plot_line, slope=widgets.FloatSlider(min=-4, max=4, step=.1), intercept=widgets.FloatSlider(min=-4, max=4, step=.1));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='slope', max=4.0, min=-4.0), FloatSlider(value=0.0, d…

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# You can probably find a reasonable-looking line by just eyeballing it.  But remember: the least-squares regression line minimizes the mean of the squared errors made by the line for each point.  Your eye might not be able to judge squared errors very well.
#
# #### A note on mean and total squared error
#
# It is common to think of the least-squares line as the line with the least *mean* squared error (or the square root of the mean squared error), as the textbook does.
#
# But it turns out that it doesn't matter whether you minimize the mean squared error or the *total* squared error.  You'll get the same best line in either case.
#
# That's because the total squared error is just the mean squared error multipled by the number of points (`d.num_rows`).  So if one line gets a better total squared error than another line, then it also gets a better mean squared error.  In particular, the line with the smallest total squared error is also better than every other line in terms of mean squared error.  That makes it the least squares line.
#
# **tl; dr:** Minimizing the mean squared error minimizes the total squared error as well.

# %% [markdown]
# #### Question 2 (Ungraded, but you'll need the result later)
# The next cell produces a more useful plot.  Use it to find a line that's closer to the least-squares regression line, keeping the above note in mind.

# %%
def plot_line_and_errors(slope, intercept):
    plt.figure(figsize=(5,5))
    points = make_array(-2, 7)
    p = plt.plot(points, slope*points + intercept, color='orange', label='Proposed line')
    ax = p[0].axes
    
    predicted_ys = slope*d.column('x') + intercept
    diffs = predicted_ys - d.column('y')
    for i in np.arange(d.num_rows):
        x = d.column('x').item(i)
        y = d.column('y').item(i)
        diff = diffs.item(i)
        
        if diff > 0:
            bottom_left_x = x
            bottom_left_y = y
        else:
            bottom_left_x = x + diff
            bottom_left_y = y + diff
        
        ax.add_patch(patches.Rectangle(make_array(bottom_left_x, bottom_left_y), abs(diff), abs(diff), color='red', alpha=.3, label=('Squared error' if i == 0 else None)))
        plt.plot(make_array(x, x), make_array(y, y + diff), color='red', alpha=.6, label=('Error' if i == 0 else None))
    
    plt.scatter(d.column('x'), d.column('y'), color='blue', label='Points')
    
    plt.xlim(-4, 8)
    plt.ylim(-6, 6)
    plt.gca().set_aspect('equal', adjustable='box')
    
    plt.legend(bbox_to_anchor=(1.8, .8))
    plt.show()

interact(plot_line_and_errors, slope=widgets.FloatSlider(min=-4, max=4, step=.1), intercept=widgets.FloatSlider(min=-4, max=4, step=.1));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='slope', max=4.0, min=-4.0), FloatSlider(value=0.0, d…

# %% [markdown]
# #### Question 3
# Describe the visual criterion you used to find a line in question 2. How did you judge whether one line was better than another?
#
# For example, a possible (but incorrect) answer is, "I tried to make the red line for the bottom-right point as small as possible."

# %% [markdown]
# I tried to make most of the points' error lines be as small as possible.

# %% [markdown]
# #### Question 4
# We can say that a point influences the line by how much the line would move if the point were removed from the data set. Does the outlier at (3, 2) have more or less influence than any other point on the resulting best-fit line?
#
# Assign `more_influence` to `True` if the outlier (3,2) has more influence than any other point on the best-fit line, or `False` if it does not.

# %%
more_influence = False

# %%
check('tests/q2_4.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# Now, let's have Python find this line for us.  When we use `minimize`, Python goes through a process similar to the one you might have used in question 2.
#
# But Python can't look at a plot that displays errors!  Instead, we tell it how to find the total squared error for a line with a given slope and intercept.

# %% [markdown]
# #### Question 5
# Define a function called `total_squared_error`.  It should take two numbers as arguments:
#
# 1. the slope of some potential line
# 2. the intercept of some potential line
#
# It should return the total squared error when we use that line to make predictions for the dataset `d`.
#
# Recall that `d` has two columns: _x_ and _y_.

# %%
def total_squared_error(slope, intercept):
    predictions = slope * (d.column(0)) + intercept
    errors = (d.column(1) - predictions)
    return sum(errors **2)

# %%
check('tests/q2_5.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# #### Question 6
# What is the total squared error for the line you found by "eyeballing" the errors in Question 1?  What about Question 2, where you made a guess that was "aided" by a visualization of the squared error?  (It's okay if the error went up, but for many students, the error will go down when using the visual aid.)

# %%
eyeballed_error = total_squared_error(-0.5, 1.2)
aided_error = total_squared_error(-1,2.3)
print("Eyeballed error:", eyeballed_error, "\nAided error:", aided_error)
# Out:
# Eyeballed error: 11.649999999999999
# Aided error: 12.999999999999998

# %%
check('tests/q2_6.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# #### Question 7
# Use `minimize` to find the slope and intercept for the line that minimizes the total squared error. This is the definition of a least-squares regression line.
#
# **Note:** `minimize` will return a single array containing the slope as the first element and intercept as the second. Read more of its documentation [here](http://data8.org/datascience/util.html?highlight=minimize#datascience.util.minimize) or an example of its use [here](https://www.inferentialthinking.com/chapters/15/3/method-of-least-squares.html).

# %%
# The staff solution used 1 line of code above here.
params = minimize(total_squared_error)
slope_from_minimize = params[0]
intercept_from_minimize = params[1]
print("Least-squares regression line: predicted_y =",
      slope_from_minimize,
      "* x + ",
      intercept_from_minimize)
# Out:
# Least-squares regression line: predicted_y = -0.6498374231570391 * x +  1.1988619620992735

# %%
check('tests/q2_7.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# #### Question 8
# What is the total squared error for the least-squares regression line that you found?

# %%
best_total_squared_error = 12.4
best_total_squared_error
# Out:
# 12.4

# %%
check('tests/q2_8.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# Finally, run the following cell to plot this "best fit" line and its errors:

# %%
plot_line_and_errors(slope_from_minimize, intercept_from_minimize)

# %% [markdown]
# ## 3. Quantifying Sampling Errors in Regression

# %% [markdown]
# Previously, in this class we've used confidence intervals to quantify uncertainty about estimates as well as to test predictions. To run a hypothesis test using a confidence interval, we use the following procedure:
# 1. Formulate a null hypothesis
# 2. Formulate an alternative hypothesis
# 3. Choose a test statistic and compute the observed value for the test statistic
# 4. Bootstrap, finding a value of the test stat for each resample
# 5. Generate a 95% confidence interval from those resampled test stats
# 6. Based on whether your value is in an interval, make a conclusion
#
# Another thing we've covered recently is the use of linear regression to make predictions, using correlated variables. An example is, say, predicting the height of children based on the heights of their parents.
#
# We can combine these two topics together in order to make even more powerful statements about our population given just a sample as before. We can use the following techniques to do so:
# - Bootstrapped interval for the true slope
# - Bootstrapped prediction interval for y (given a particular value of x)
#
# This homework further explores these two advanced methods.

# %% [markdown]
# Recall the Old Faithful dataset from our lab on regression. The table contains two pieces of information about each eruption of the Old Faithful geyser in Yellowstone National Park:
# 1. The duration of the eruption, in minutes.
# 2. The time between this eruption and the next eruption (the "waiting time"), in minutes.
#
# The dataset is plotted below along with its line of best fit.

# %%
faithful = Table.read_table('faithful_inference.csv')
faithful.scatter('duration', fit_line=True)
faithful
# Out:
# duration | wait
# 3.6      | 79
# 1.8      | 54
# 3.333    | 74
# 2.283    | 62
# 4.533    | 85
# 2.883    | 55
# 4.7      | 88
# 3.6      | 85
# 1.95     | 51
# 4.35     | 85
# ... (262 rows omitted)

# %% [markdown]
# ### Finding the Bootstrap Confidence Interval for the True Slope
#
# Last time we looked at this dataset, we noticed the apparent linear relationship between duration and wait, and we decided to use regression to predict wait in terms of duration. However, our data are just a sample of all the eruptions that have happened at Old Faithful. As we know, relationships can appear in a sample that don't really exist in the population from which the sample was taken.

# %% [markdown]
# #### Question 1
#
# Before we move forward using our linear model, we would like to know whether or not there truly exists a relationship between duration and wait time. If there is no relationship between the two, then we'd expect a correlation of 0, which would give us a slope of 0. Now, write in null and alternative hypotheses, based on your knowledge of hypothesis tests you've conducted in the past.

# %% [markdown]
# - **Null Hypothesis:** There is no correlation between duration and wait of Old Faithful
# - **Alternate Hypothesis:** There is correlation between duration and wait of Old Faithful

# %% [markdown]
# We will use the method of confidence intervals to test this hypothesis.
#
# <div class="hide">\pagebreak</div>
#
# #### Question 2
#
# We'll warm up by implementing some familiar functions. You may use these functions throughout this assignment. Start by defining these two functions:
#
# 1. `standard_units` should take in an array of numbers and return an array containing those numbers converted to standard units.
# 2. `correlation` should take in a table with 2 columns and return the correlation between these columns. Hint: you may want to use the `standard_units` function you defined above.

# %%
def standard_units(arr):
    return (arr - np.mean(arr))/np.std(arr)

def correlation(tbl):
    return np.mean(standard_units(tbl.column(0))*standard_units(tbl.column(1)))

# %%
check('tests/q3_2.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 3
#
# Using the functions you just implemented, create a function called `fit_line`.  It should take a table as its argument.  It should return an array containing the slope and intercept of the regression line that predicts the second column in the table using the first.

# %%
def fit_line(tbl):
    slope = correlation(tbl)*np.std(tbl.column(1))/np.std(tbl.column(0))
    intercept = np.mean(tbl.column(1)) - slope*(np.mean(tbl.column(0)))
    return make_array(slope, intercept)

# This should compute the slope and intercept of the regression
# line predicting wait time from duration in the faithful dataset.
fit_line(faithful)
# Out:
# array([10.7296414 , 33.47439702])

# %%
# Ensure your fit_line function fits a reasonable line 
# to the data in faithful, using the plot below

slope, intercept = fit_line(faithful)
faithful.scatter(0)
plt.plot([min(faithful[0]), max(faithful[0])], 
         [slope*min(faithful[0])+intercept, slope*max(faithful[0])+intercept])
plt.show()

# %%
check('tests/q3_3.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# Now we have all the tools we need in order to create a confidence interval quantifying our uncertainty about the true relationship between duration and wait time.

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 4
#
# Use the bootstrap to compute 1000 resamples from our dataset. For each resample, compute the slope of the best fit line. Put these slopes in an array called `resample_slopes`, giving you the empirical distribution of regression line slopes in resamples. Plot a histogram of these slopes.

# %%
resample_slopes = make_array()
for i in np.arange(1000):
    a = faithful.sample()
    b = fit_line(a).item(0)
    resample_slopes = np.append(resample_slopes,b)
Table().with_column('resample slopes', resample_slopes).hist()

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 5
#
# Use your resampled slopes to construct an approximate 95% confidence interval for the true value of the slope.

# %%
lower_end = percentile(2.5, resample_slopes)
upper_end = percentile(97.5, resample_slopes)
print("95% confidence interval for slope: [{:g}, {:g}]".format(lower_end, upper_end))
# Out:
# 95% confidence interval for slope: [10.1424, 11.3402]

# %%
check('tests/q3_5.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 6
#
# Based on your confidence interval, would you accept or reject the null hypothesis that the true slope is 0?  Why?  What P-value cutoff are you using?

# %% [markdown]
# Based on the confidence interval, I would reject the null hypothesis because noen of the resampled slopes are 0.

# %% [markdown]
# ### Finding the Bootstrap Prediction Interval

# %% [markdown]
# Suppose we're tourists at Yellowstone, and we'd like to know how long we'll have to wait for the next Old Faithful eruption.  We decide to use our regression line to make some predictions for the waiting times.  But just as we're uncertain about the slope of the true regression line, we're also uncertain about the predictions we'd make based on the true regression line.

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 7
#
# Define the function `fitted_value`.  It should take 2 arguments:
#
# 1. A table with 2 columns.  We'll be predicting the values in the second column using the first.
# 2. A number, the value of the predictor variable for which we'd like to make a prediction.
#
# Make sure to use your `fit_line` function.

# %%
def fitted_value(table, given_x):
    # The staff solution took 4 lines of code.
    line = fit_line(table)
    a = line.item(0)
    b = line.item(1)
    return b+a*given_x

# Here's an example of how fitted_value is used.  This should
# compute the prediction for the wait time of an eruption that lasts 
# two minutes .
two_minutes_wait = fitted_value(faithful, 2)
two_minutes_wait
# Out:
# 54.933679813020404

# %%
check('tests/q3_7.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 8
#
# The park ranger tells us that the most recent eruption lasted 6 minutes. Using your function above, assign the variable `most_recent_wait` to the predicted wait time.

# %%
most_recent_wait = 75.4
most_recent_wait
# Out:
# 75.4

# %%
check('tests/q3_8.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# Juan, a fellow tourist, raises the following objection to your prediction:
#
# > "Your prediction depends on your sample of 272 eruptions.  Couldn't your prediction have been different if you had happened to have a different sample of eruptions?"
#
# Having read section [16.3](https://www.inferentialthinking.com/chapters/16/3/prediction-intervals.html) of the textbook, you know just the response!

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 9
#
# Define the function `bootstrap_lines`.  It should take two arguments:
# 1. A table with two columns.  As usual, we'll be predicting the second column using the first.
# 2. An integer, a number of bootstraps to run.
#
# It should return a *table* whose first column, `"Slope"`, contains the given number of bootstrapped slopes, and whose second column, `"Intercept"`, contains the corresponding bootstrapped intercepts.  Each slope and intercept should come from a regression line that predicts column 2 from column 1 of a resample of the given table.  The table should have 1 row for each bootstrap replication.

# %%
def bootstrap_lines(tbl, num_bootstraps):
    slopes = make_array()
    intercepts = make_array()
    for i in np.arange(num_bootstraps):
        resample = tbl.sample(tbl.num_rows, with_replacement = True)
        parameters = fit_line(resample)
        slopes = np.append(slopes, parameters[0])
        intercepts = np.append(intercepts, parameters[1])
    return Table().with_columns('Slope', slopes, 'Intercept', intercepts)

# When you're done, this code should produce the slopes
# and intercepts of 1000 regression lines computed from
# resamples of the faithful table.
regression_lines = bootstrap_lines(faithful, 1000)
regression_lines
# Out:
# Slope   | Intercept
# 11.2216 | 31.991
# 10.4344 | 34.9644
# 11.1928 | 31.4909
# 10.5293 | 33.7839
# 10.465  | 34.8663
# 10.2149 | 34.9899
# 10.6343 | 33.9358
# 10.6713 | 33.1432
# 10.804  | 32.6477
# 10.4749 | 34.534
# ... (990 rows omitted)

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 10
#
# Create an array called `predictions_for_six`.  It should contain 1000 numbers.  Each number should be the predicted waiting time after an eruption with a duration of 6 minutes, using a different bootstrapped regression line. Hint: use `regression_lines` from the previous questions.

# %%
predictions_for_six = regression_lines.column(0)* 6 + regression_lines.column(1)

# This will make a histogram of your predictions:
table_of_predictions = Table().with_column('Predictions at eruptions=6', predictions_for_six)
table_of_predictions.hist('Predictions at eruptions=6', bins=20)

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 11
#
# Create a 95 percent confidence interval for these predictions.

# %%
lower_bound = percentile(2.5, predictions_for_six)
upper_bound = percentile(97.5, predictions_for_six)

print('95% Confidence interval for predictions for x=6: (', lower_bound,",", upper_bound, ')')
# Out:
# 95% Confidence interval for predictions for x=6: ( 96.3581963837853 , 99.50717119536654 )

# %%
check('tests/q3_11.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# <div class="hide">\pagebreak</div>
#
# #### Question 12
#
# Look at the scatter plot of the data at the start of this exercise.
# Determine which of the following are true, then set `question_12_choice` to an array consisting of the numbers of statements that are true. For example, if you think that 1 and 2 are true but 3 is false, you'd assign `question_12_choice` to be an array consisting of the values 1 and 2.
#
# Statement 1: This confidence covers 95 percent of waiting times of eruptions in `faithful` that had an eruption duration of 6 minutes.
#
# Statement 2: This interval gives a sense of how much actual wait times differ from your prediction.
#
# Statement 3: The confidence interval quantifies our uncertainty in our estimate of what the true regression line would predict.

# %%
question_12_choice = [1,2,3]

# %%
check('tests/q3_12.py')
# Out:
#
#
#         <p>All tests passed!</p>

# %% [markdown]
# ## 4. Submission

# %% [markdown]
# Congratulations, you're done with Homework 11!  Be sure to
# - **run all the tests and verify that they all pass** (the next cell has a shortcut for that),
# - **Save and Checkpoint** from the `File` menu,
# - **Hit the Submit button** Your submission will be saved and grade will be posted when it's finished running.

# %%
# For your convenience, you can run this cell to run all the tests at once!
import glob
from gofer.ok import grade_notebook
if not globals().get('__GOFER_GRADER__', False):
    display(grade_notebook('hw11.ipynb', sorted(glob.glob('tests/q*.py'))))
# Out:
# Question 1:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q1_1.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #666666">36000</span> <span style="color: #666666">&lt;=</span> <span style="color: #008000">sum</span>(residuals(boston)<span style="color: #666666">**2</span>) <span style="color: #666666">&lt;=</span> <span style="color: #666666">37000</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     36000 <= sum(residuals(boston)**2) <= 37000
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q1_1.py 0
# Failed example:
#     36000 <= sum(residuals(boston)**2) <= 37000
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q1_1.py 0[0]>", line 1, in <module>
#         36000 <= sum(residuals(boston)**2) <= 37000
#     NameError: name 'residuals' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 2:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q1_4.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #008000">type</span>(linear) <span style="color: #666666">==</span> <span style="color: #008000">bool</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     type(linear) == bool
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q1_4.py 0
# Failed example:
#     type(linear) == bool
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q1_4.py 0[0]>", line 1, in <module>
#         type(linear) == bool
#     NameError: name 'linear' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 3:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q1_5.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>np<span style="color: #666666">.</span>round(boston_residual_sd,<span style="color: #666666">2</span>) <span style="color: #666666">==</span> <span style="color: #666666">8.47</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     np.round(boston_residual_sd,2) == 8.47
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q1_5.py 0
# Failed example:
#     np.round(boston_residual_sd,2) == 8.47
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q1_5.py 0[0]>", line 1, in <module>
#         np.round(boston_residual_sd,2) == 8.47
#     NameError: name 'np' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 4:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q1_6.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>np<span style="color: #666666">.</span>round(faithful_residual_sd,<span style="color: #666666">2</span>) <span style="color: #666666">==</span> <span style="color: #666666">5.89</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     np.round(faithful_residual_sd,2) == 5.89
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q1_6.py 0
# Failed example:
#     np.round(faithful_residual_sd,2) == 5.89
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q1_6.py 0[0]>", line 1, in <module>
#         np.round(faithful_residual_sd,2) == 5.89
#     NameError: name 'np' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 5:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q2_4.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #008000">type</span>(more_influence) <span style="color: #666666">==</span> <span style="color: #008000">bool</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     type(more_influence) == bool
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q2_4.py 0
# Failed example:
#     type(more_influence) == bool
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_4.py 0[0]>", line 1, in <module>
#         type(more_influence) == bool
#     NameError: name 'more_influence' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 6:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q2_5.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># It looks like you forgot to return something.</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>total_squared_error(<span style="color: #666666">0</span>, <span style="color: #666666">0</span>) <span style="color: #AA22FF; font-weight: bold">is</span> <span style="color: #AA22FF; font-weight: bold">not</span> <span style="color: #008000">None</span>
# <span style="color: #888888">True</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># It looks like you took a square root, but</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># we didn&#39;t want you to do that in this exercise.</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>np<span style="color: #666666">.</span>isclose(<span style="color: #666666">15.25**0.5</span>, total_squared_error(<span style="color: #666666">0</span>, <span style="color: #666666">0</span>))
# <span style="color: #888888">False</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># Your calculation is incorrect in some way.</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>np<span style="color: #666666">.</span>isclose(<span style="color: #666666">15.25</span>, total_squared_error(<span style="color: #666666">0</span>, <span style="color: #666666">0</span>))
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     total_squared_error(0, 0) is not None
# Expecting:
#     True
# **********************************************************************
# Line 3, in tests/q2_5.py 0
# Failed example:
#     total_squared_error(0, 0) is not None
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_5.py 0[0]>", line 1, in <module>
#         total_squared_error(0, 0) is not None
#     NameError: name 'total_squared_error' is not defined
# Trying:
#     np.isclose(15.25**0.5, total_squared_error(0, 0))
# Expecting:
#     False
# **********************************************************************
# Line 7, in tests/q2_5.py 0
# Failed example:
#     np.isclose(15.25**0.5, total_squared_error(0, 0))
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_5.py 0[1]>", line 1, in <module>
#         np.isclose(15.25**0.5, total_squared_error(0, 0))
#     NameError: name 'np' is not defined
# Trying:
#     np.isclose(15.25, total_squared_error(0, 0))
# Expecting:
#     True
# **********************************************************************
# Line 10, in tests/q2_5.py 0
# Failed example:
#     np.isclose(15.25, total_squared_error(0, 0))
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_5.py 0[2]>", line 1, in <module>
#         np.isclose(15.25, total_squared_error(0, 0))
#     NameError: name 'np' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 7:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q2_6.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #666666">10.9</span> <span style="color: #666666">&lt;=</span> eyeballed_error <span style="color: #666666">&lt;=</span> <span style="color: #666666">14</span>
# <span style="color: #888888">True</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #666666">10.9</span> <span style="color: #666666">&lt;=</span> aided_error <span style="color: #666666">&lt;=</span> <span style="color: #666666">14</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     10.9 <= eyeballed_error <= 14
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q2_6.py 0
# Failed example:
#     10.9 <= eyeballed_error <= 14
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_6.py 0[0]>", line 1, in <module>
#         10.9 <= eyeballed_error <= 14
#     NameError: name 'eyeballed_error' is not defined
# Trying:
#     10.9 <= aided_error <= 14
# Expecting:
#     True
# **********************************************************************
# Line 4, in tests/q2_6.py 0
# Failed example:
#     10.9 <= aided_error <= 14
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_6.py 0[1]>", line 1, in <module>
#         10.9 <= aided_error <= 14
#     NameError: name 'aided_error' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 8:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q2_7.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #666666">-1</span> <span style="color: #666666">&lt;=</span> slope_from_minimize <span style="color: #666666">&lt;=</span> <span style="color: #666666">0</span>
# <span style="color: #888888">True</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #666666">0</span> <span style="color: #666666">&lt;=</span> intercept_from_minimize <span style="color: #666666">&lt;=</span> <span style="color: #666666">2</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     -1 <= slope_from_minimize <= 0
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q2_7.py 0
# Failed example:
#     -1 <= slope_from_minimize <= 0
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_7.py 0[0]>", line 1, in <module>
#         -1 <= slope_from_minimize <= 0
#     NameError: name 'slope_from_minimize' is not defined
# Trying:
#     0 <= intercept_from_minimize <= 2
# Expecting:
#     True
# **********************************************************************
# Line 4, in tests/q2_7.py 0
# Failed example:
#     0 <= intercept_from_minimize <= 2
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_7.py 0[1]>", line 1, in <module>
#         0 <= intercept_from_minimize <= 2
#     NameError: name 'intercept_from_minimize' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 9:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q2_8.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #666666">10.9</span> <span style="color: #666666">&lt;=</span> best_total_squared_error <span style="color: #666666">&lt;=</span> <span style="color: #666666">14</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     10.9 <= best_total_squared_error <= 14
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q2_8.py 0
# Failed example:
#     10.9 <= best_total_squared_error <= 14
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q2_8.py 0[0]>", line 1, in <module>
#         10.9 <= best_total_squared_error <= 14
#     NameError: name 'best_total_squared_error' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 10:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q3_11.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>lower_bound <span style="color: #666666">&gt;</span> <span style="color: #666666">80</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     lower_bound > 80
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q3_11.py 0
# Failed example:
#     lower_bound > 80
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q3_11.py 0[0]>", line 1, in <module>
#         lower_bound > 80
#     NameError: name 'lower_bound' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 11:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q3_12.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># Your choice should be one of the options</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #008000">type</span>(question_12_choice) <span style="color: #666666">==</span> <span style="color: #008000">list</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     type(question_12_choice) == list
# Expecting:
#     True
# **********************************************************************
# Line 3, in tests/q3_12.py 0
# Failed example:
#     type(question_12_choice) == list
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q3_12.py 0[0]>", line 1, in <module>
#         type(question_12_choice) == list
#     NameError: name 'question_12_choice' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 12:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q3_2.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># Ensure your correlation function returns one number between -1 and 1</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #008000">abs</span>(correlation(Table()<span style="color: #666666">.</span>with_columns(<span style="color: #BA2121">&#39;a&#39;</span>, np<span style="color: #666666">.</span>random<span style="color: #666666">.</span>normal(<span style="color: #666666">0</span>, <span style="color: #666666">1</span>, <span style="color: #666666">10</span>),<span style="color: #BA2121">&#39;b&#39;</span>, np<span style="color: #666666">.</span>random<span style="color: #666666">.</span>normal(<span style="color: #666666">0</span>, <span style="color: #666666">1</span>, <span style="color: #666666">10</span>)))) <span style="color: #666666">&lt;=</span> <span style="color: #666666">1</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     abs(correlation(Table().with_columns('a', np.random.normal(0, 1, 10),'b', np.random.normal(0, 1, 10)))) <= 1
# Expecting:
#     True
# **********************************************************************
# Line 3, in tests/q3_2.py 0
# Failed example:
#     abs(correlation(Table().with_columns('a', np.random.normal(0, 1, 10),'b', np.random.normal(0, 1, 10)))) <= 1
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q3_2.py 0[0]>", line 1, in <module>
#         abs(correlation(Table().with_columns('a', np.random.normal(0, 1, 10),'b', np.random.normal(0, 1, 10)))) <= 1
#     NameError: name 'correlation' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 13:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q3_3.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #008000">len</span>(fit_line(Table()<span style="color: #666666">.</span>with_columns(<span style="color: #BA2121">&#39;x&#39;</span>, make_array(<span style="color: #666666">0</span>, <span style="color: #666666">1</span>), <span style="color: #BA2121">&#39;y&#39;</span>, make_array(<span style="color: #666666">1</span>, <span style="color: #666666">3</span>)))) <span style="color: #666666">==</span> <span style="color: #666666">2</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     len(fit_line(Table().with_columns('x', make_array(0, 1), 'y', make_array(1, 3)))) == 2
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q3_3.py 0
# Failed example:
#     len(fit_line(Table().with_columns('x', make_array(0, 1), 'y', make_array(1, 3)))) == 2
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q3_3.py 0[0]>", line 1, in <module>
#         len(fit_line(Table().with_columns('x', make_array(0, 1), 'y', make_array(1, 3)))) == 2
#     NameError: name 'fit_line' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 14:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q3_5.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span>lower_end <span style="color: #666666">&gt;</span> <span style="color: #666666">5</span>
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     lower_end > 5
# Expecting:
#     True
# **********************************************************************
# Line 2, in tests/q3_5.py 0
# Failed example:
#     lower_end > 5
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q3_5.py 0[0]>", line 1, in <module>
#         lower_end > 5
#     NameError: name 'lower_end' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 15:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q3_7.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># Make sure two_minutes_wait is a single value</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #008000">isinstance</span>(two_minutes_wait, <span style="color: #008000">float</span>)
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     isinstance(two_minutes_wait, float)
# Expecting:
#     True
# **********************************************************************
# Line 3, in tests/q3_7.py 0
# Failed example:
#     isinstance(two_minutes_wait, float)
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q3_7.py 0[0]>", line 1, in <module>
#         isinstance(two_minutes_wait, float)
#     NameError: name 'two_minutes_wait' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# Question 16:
#
#
#         <p>0 of 1 tests passed</p>
#
#
#         <p> <strong>Tests failed: </strong>
#             <ul>
#
#                 <li>
#     <p><strong style='color: red;'>tests/q3_8.py</strong></p>
#
#     <p><strong>Test code:</strong><pre><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%"><span></span><span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #408080; font-style: italic"># Make sure most_recent_wait is a single value</span>
# <span style="color: #000080; font-weight: bold">&gt;&gt;&gt; </span><span style="color: #008000">isinstance</span>(most_recent_wait, <span style="color: #008000">float</span>)
# <span style="color: #888888">True</span>
# </pre></div>
# </pre></p>
#
#     <p><strong>Test result:</strong><pre>Trying:
#     isinstance(most_recent_wait, float)
# Expecting:
#     True
# **********************************************************************
# Line 3, in tests/q3_8.py 0
# Failed example:
#     isinstance(most_recent_wait, float)
# Exception raised:
#     Traceback (most recent call last):
#       File "/srv/conda/envs/notebook/lib/python3.7/doctest.py", line 1329, in __run
#         compileflags, 1), test.globs)
#       File "<doctest tests/q3_8.py 0[0]>", line 1, in <module>
#         isinstance(most_recent_wait, float)
#     NameError: name 'most_recent_wait' is not defined
# </pre></p>
#      </li>
#
#             </ul>
# 0.0
